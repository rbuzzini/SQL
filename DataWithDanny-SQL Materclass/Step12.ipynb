# %% [markdown]
# # Step 12 - Final Case Study Questions
#
# To finish up our entire cryptocurrency case study - let's now calculate exactly the same query that we just created for Nandita's data with our entire dataset with all mentors included!
#
# ## Create The Base Table
# Create a summary table `mentor_performance` which includes the following metrics for each member and ticker:
#
# - Count of purchase transactions
# - Initial investment
# - Purchase fees
# - Dollar cost average of purchases
# - Count of sales transactions
# - Gross revenue amount
# - Sales fees
# - Average selling price
# - Actual Profitability (final portfolio value + gross sales revenue - purchase fees - sales fees) / initial investment amount
# - Theoretical Profitability (final portfolio value with no sales - purchase fees) / initial investment amount

# %%
# Importing packages:
import pandas as pd
import os
import sqlalchemy

# Connecting to MySQL database:
host = os.environ.get('mysql_host')
user = os.environ.get('mysql_user')
password = os.environ.get('mysql_password')
engine = sqlalchemy.create_engine(f'mysql+pymysql://{user}:{password}@{host}/trading')

# %%
query = """
WITH cte_portfolio AS (
  SELECT
    members.first_name,
    members.region,
    transactions.ticker,
    transactions.txn_type,
    COUNT(*) AS transaction_count,
    SUM(transactions.quantity) AS total_quantity,
    SUM(transactions.quantity * prices.price) AS gross_values,
    SUM(transactions.quantity * prices.price * transactions.percentage_fee / 100) AS fees 
  FROM trading.transactions
  INNER JOIN trading.members
    ON transactions.member_id = members.member_id
  INNER JOIN trading.prices
    ON transactions.ticker = prices.ticker
    AND transactions.txn_date = prices.market_date
  GROUP BY
    members.first_name,
    members.region,
    transactions.ticker,
    transactions.txn_type
),
cte_summary AS (
  SELECT
    first_name,
    region,
    ticker,
    SUM(
      CASE
        WHEN txn_type = 'BUY' THEN total_quantity
        WHEN txn_type = 'SELL' THEN -total_quantity
      END
    ) AS final_quantity,
    SUM(CASE WHEN txn_type = 'BUY' THEN gross_values ELSE 0 END) AS initial_investment,
    SUM(CASE WHEN txn_type = 'SELL' THEN gross_values ELSE 0 END) AS sales_revenue,
    SUM(CASE WHEN txn_type = 'BUY' THEN fees ELSE 0 END) AS purchase_fees,
    SUM(CASE WHEN txn_type = 'SELL' THEN fees ELSE 0 END) AS sales_fees,
    SUM(CASE WHEN txn_type = 'BUY' THEN total_quantity ELSE 0 END) AS purchase_quantity,
    SUM(CASE WHEN txn_type = 'SELL' THEN total_quantity ELSE 0 END) AS sales_quantity,
    SUM(CASE WHEN txn_type = 'BUY' THEN transaction_count ELSE 0 END) AS purchase_transactions,
    SUM(CASE WHEN txn_type = 'SELL' THEN transaction_count ELSE 0 END) AS sales_transactions
  FROM cte_portfolio
  GROUP BY
    first_name,
    region,
    ticker
),
cte_metrics AS (
  SELECT
    summary.first_name,
    summary.region,
    summary.ticker,
    summary.final_quantity * final.price AS actual_final_value,
    summary.purchase_quantity * final.price AS theoretical_final_value,
    summary.sales_revenue,
    summary.purchase_fees,
    summary.sales_fees,
    summary.initial_investment,
    summary.purchase_quantity,
    summary.sales_quantity,
    summary.purchase_transactions,
    summary.sales_transactions,
    summary.initial_investment / purchase_quantity AS dollar_cost_average,
    summary.sales_revenue / sales_quantity AS average_selling_price
  FROM cte_summary AS summary
  INNER JOIN trading.prices AS final
    ON summary.ticker = final.ticker
  WHERE final.market_date = '2021-08-29'
)
SELECT
  first_name,
  region,
  ticker,
  actual_final_value AS final_portfolio_value,
  ( actual_final_value + sales_revenue - purchase_fees - sales_fees ) / initial_investment AS actual_profitability,
  ( theoretical_final_value - purchase_fees ) / initial_investment AS theoretical_profitability,
  dollar_cost_average,
  average_selling_price,
  sales_revenue,
  purchase_fees,
  sales_fees,
  initial_investment,
  purchase_quantity,
  sales_quantity,
  purchase_transactions,
  sales_transactions
FROM cte_metrics;
"""

mentor_performance = pd.read_sql_query(query, engine)
mentor_performance.to_sql(
  name='mentor_performance',
  con=engine,
  index=False,
  if_exists='replace',
)

# %%
pd.read_sql_query(
    """
    SELECT *
    FROM mentor_performance
    """,
    engine
)
# Out:
#    first_name         region ticker  final_portfolio_value  \
# 0       Vipul  United States    ETH           1.310256e+07
# 1        Alex  United States    ETH           8.166075e+06
# 2         Abe  United States    ETH           6.639150e+06
# 3       Danny      Australia    ETH           1.113844e+07
# 4       Sonia      Australia    ETH           1.132069e+07
# 5         Ben      Australia    ETH           1.342841e+07
# 6     Nandita  United States    ETH           1.113479e+07
# 7        Leah           Asia    ETH           5.011671e+06
# 8     Charlie  United States    ETH           5.655596e+06
# 9       Enoch         Africa    ETH           2.183933e+06
# 10      Pavan      Australia    ETH           4.188487e+06
# 11     Vikram          India    ETH           6.276427e+06
# 12      Ayush  United States    ETH           1.311605e+06
# 13      Rowan  United States    ETH           4.678643e+06
# 14       Alex  United States    BTC           1.062253e+08
# 15      Ayush  United States    BTC           1.903755e+08
# 16        Abe  United States    BTC           1.795335e+08
# 17      Rowan  United States    BTC           1.239676e+08
# 18     Vikram          India    BTC           1.668132e+08
# 19        Ben      Australia    BTC           1.744955e+08
# 20       Leah           Asia    BTC           1.952441e+08
# 21      Vipul  United States    BTC           7.850296e+07
# 22      Danny      Australia    BTC           1.594770e+08
# 23      Enoch         Africa    BTC           1.705807e+08
# 24      Sonia      Australia    BTC           1.242848e+08
# 25    Nandita  United States    BTC           2.007514e+08
# 26      Pavan      Australia    BTC           7.487663e+07
# 27    Charlie  United States    BTC           1.225342e+08
#
#     actual_profitability  theoretical_profitability  dollar_cost_average  \
# 0               4.672466                   5.314622           597.667322
# 1               5.160549                   6.195711           512.700544
# 2               6.306367                   6.966968           455.956219
# 3               5.082495                   6.230089           509.872366
# 4               4.478792                   5.292087           600.197716
# 5               5.566492                   5.798154           547.840959
# 6               4.941266                   5.308057           598.397258
# 7               4.270687                   5.483030           579.309227
# 8               4.384908                   5.823239           545.483350
# 9               2.927689                   5.826837           545.139758
# 10              3.854468                   6.164973           515.248248
# 11              4.311813                   5.899722           538.402091
# 12              2.687034                   5.816251           546.136841
# 13              5.074270                   6.704493           473.813549
# 14              3.171349                   3.647323         13221.315860
# 15              3.606659                   3.945872         12221.424297
# 16              3.450229                   4.025738         11978.892836
# 17              3.216046                   3.994808         12071.725777
# 18              3.527151                   3.955991         12190.138446
# 19              3.580810                   3.726439         12940.572771
# 20              3.207139                   3.695850         13047.716423
# 21              2.687145                   3.682943         13093.314469
# 22              3.152154                   3.863233         12482.566266
# 23              3.322104                   3.813496         12645.174890
# 24              3.222392                   3.980176         12116.192560
# 25              3.318955                   3.800968         12686.918722
# 26              2.961701                   4.194469         11497.419922
# 27              3.725216                   4.008656         12029.849981
#
#     average_selling_price  sales_revenue  purchase_fees    sales_fees  \
# 0              626.242026   4.567939e+05    7104.570101   1188.379519
# 1              594.103480   3.943560e+05    4190.281069   1055.122692
# 2              402.869593   1.024365e+05    2830.408924    280.268725
# 3              566.702622   5.732548e+05    5824.685434   1455.005348
# 4              547.838968   4.445042e+05    6743.608509   1074.114552
# 5              575.241107   1.245384e+05    6102.489005    311.466406
# 6              542.484897   1.725919e+05    5783.326972    447.938122
# 7              661.522994   4.035602e+05    3216.060293    986.188546
# 8              636.245975   5.052154e+05    3500.084034   1162.340573
# 9              571.750353   6.045780e+05    2441.665069   1602.260204
# 10             531.294866   5.720455e+05    3229.569685   1350.079800
# 11             576.741882   5.572259e+05    4169.628670   1467.039242
# 12             472.423275   3.340036e+05    1535.335589    874.602681
# 13             451.534966   2.626633e+05    2383.355744    617.385747
# 14           10912.780841   4.864305e+06   86273.626334  12991.807515
# 15           11627.473428   5.849093e+06  137094.220812  15782.142294
# 16           11297.724786   9.629773e+06  142276.808335  24216.727376
# 17           14698.463754   1.467463e+07  109785.905500  34896.998038
# 18           11616.444311   6.676932e+06  124651.516624  16956.792783
# 19           12007.502752   2.379059e+06  124879.663628   6292.825381
# 20           14163.271120   1.316702e+07  162182.815230  34511.925256
# 21           13475.453945   1.312637e+07   86003.424712  33121.339845
# 22           12136.898145   1.305399e+07  139898.662769  33921.865821
# 23           12221.728676   8.993631e+06  139549.790354  22127.737880
# 24           13301.414907   1.218813e+07  106218.643188  32557.523374
# 25           12710.973143   1.097575e+07  162919.948952  29522.093986
# 26           12736.346399   1.310214e+07   75946.046744  35021.694106
# 27           16533.362948   5.048388e+06   89519.450721  13459.650970
#
#     initial_investment  purchase_quantity  sales_quantity  \
# 0         2.900194e+06        4852.521567      729.420717
# 1         1.657805e+06        3233.476848      663.783429
# 2         1.068519e+06        2343.469084      254.267181
# 3         2.302888e+06        4516.597244     1011.561933
# 4         2.625122e+06        4373.762105      811.377514
# 5         2.433585e+06        4442.136852      216.497826
# 6         2.287097e+06        3822.037200      318.150636
# 7         1.267016e+06        2187.115438      610.047063
# 8         1.403940e+06        2573.754758      794.056716
# 9         9.510804e+05        1744.654252     1057.415964
# 10        1.233880e+06        2394.730037     1076.700581
# 11        1.583560e+06        2941.222308      966.161738
# 12        6.115287e+05        1119.735333      707.000729
# 13        9.732051e+05        2053.983325      581.712064
# 14        3.499784e+07        2647.076835      445.743862
# 15        5.436381e+07        4448.238805      503.040727
# 16        5.477804e+07        4572.880092      852.363881
# 17        4.306453e+07        3567.388251      998.378533
# 18        4.914689e+07        4031.692577      574.782800
# 19        4.935848e+07        3814.242469      198.131020
# 20        6.492218e+07        4975.750639      929.659744
# 21        3.405481e+07        2600.930874      974.095023
# 22        5.467917e+07        4380.442928     1075.562607
# 23        5.400574e+07        4270.857378      735.872224
# 24        4.230838e+07        3491.887391      916.303279
# 25        6.373535e+07        5023.705689      863.485821
# 26        2.966802e+07        2580.406459     1028.720085
# 27        3.422073e+07        2844.651550      305.345490
#
#     purchase_transactions  sales_transactions
# 0                   991.0               149.0
# 1                   651.0               136.0
# 2                   452.0                49.0
# 3                   904.0               200.0
# 4                   864.0               161.0
# 5                   877.0                44.0
# 6                   756.0                70.0
# 7                   435.0               126.0
# 8                   501.0               158.0
# 9                   351.0               209.0
# 10                  462.0               215.0
# 11                  577.0               204.0
# 12                  222.0               145.0
# 13                  398.0               127.0
# 14                  534.0                84.0
# 15                  879.0                95.0
# 16                  900.0               171.0
# 17                  731.0               192.0
# 18                  792.0               115.0
# 19                  738.0                38.0
# 20                  985.0               178.0
# 21                  491.0               202.0
# 22                  841.0               216.0
# 23                  820.0               146.0
# 24                  692.0               192.0
# 25                  954.0               167.0
# 26                  526.0               197.0
# 27                  557.0                51.0

# %% [markdown]
# **Question 1**
#
# Which mentors have the greatest actual profitability for each ticker?

# %% [markdown]
# I answered this question with this twisted query

# %%
pd.read_sql_query(
    """
    WITH eth_max_profitability AS (
      SELECT
        first_name,
        ticker,
        MAX(actual_profitability) AS actual_profitability
      FROM mentor_performance
      WHERE ticker='ETH'
      GROUP BY first_name, ticker
      ORDER BY actual_profitability DESC
      LIMIT 1
    ),

    btc_max_profitability AS (
      SELECT
        first_name,
        ticker,
        MAX(actual_profitability) AS actual_profitability
      FROM mentor_performance
      WHERE ticker='BTC'
      GROUP BY first_name, ticker
      ORDER BY actual_profitability DESC
      LIMIT 1
    )  
    SELECT *
    FROM btc_max_profitability
    UNION
    SELECT *
    FROM eth_max_profitability;
    """,
    engine
)
# Out:
#   first_name ticker  actual_profitability
# 0    Charlie    BTC              3.725216
# 1        Abe    ETH              6.306367

# %% [markdown]
# The following one is better:

# %%
pd.read_sql_query(
    """
    WITH cte_rank AS (
        SELECT
          first_name,
          ticker,
          actual_profitability,
          RANK() OVER (PARTITION BY ticker ORDER BY actual_profitability DESC) AS profitability_rank
        FROM mentor_performance
    )
    SELECT *
    FROM cte_rank
    WHERE profitability_rank=1;
    """,
    engine
)
# Out:
#   first_name ticker  actual_profitability  profitability_rank
# 0    Charlie    BTC              3.725216                   1
# 1        Abe    ETH              6.306367                   1

# %% [markdown]
# **Question 2**
#
# Which mentors have the greatest difference in actual vs theoretical profitability for each ticker?

# %%
pd.read_sql_query(
    """
    WITH cte_rank AS (
        SELECT
          first_name,
          ticker,
          ABS(actual_profitability - theoretical_profitability) AS profitability_delta,
          RANK() OVER (
            PARTITION BY ticker ORDER BY ABS(actual_profitability - theoretical_profitability) DESC
            ) AS profitability_delta_rank
        FROM mentor_performance
    )
    SELECT 
      *
    FROM cte_rank
    WHERE profitability_delta_rank=1;
    """,
    engine
)
# Out:
#   first_name ticker  profitability_delta  profitability_delta_rank
# 0      Pavan    BTC             1.232768                         1
# 1      Ayush    ETH             3.129217                         1

# %% [markdown]
# **Question 3**
#
# What is the total amount of sales revenue made by all mentors for each region? (combined BTC and ETH)

# %%
pd.read_sql_query(
    """
    SELECT
      region,
      SUM(sales_revenue) AS total_sales_revenue
    FROM mentor_performance
    GROUP BY region
    ORDER BY total_sales_revenue DESC;
    """,
    engine
)
# Out:
#           region  total_sales_revenue
# 0  United States         6.639637e+07
# 1      Australia         4.243766e+07
# 2           Asia         1.357058e+07
# 3         Africa         9.598209e+06
# 4          India         7.234158e+06

# %% [markdown]
# **Question 4**
#
# What is the average actual profitability for each region for each ticker?

# %%
pd.read_sql_query(
    """
    SELECT
      region,
      ticker,
      AVG(actual_profitability) AS avg_actual_profitability
    FROM mentor_performance
    GROUP BY region, ticker
    ORDER BY ticker, avg_actual_profitability DESC;
    """,
    engine
)
# Out:
#           region ticker  avg_actual_profitability
# 0          India    BTC                  3.527151
# 1         Africa    BTC                  3.322104
# 2  United States    BTC                  3.310800
# 3      Australia    BTC                  3.229264
# 4           Asia    BTC                  3.207139
# 5  United States    ETH                  4.746694
# 6      Australia    ETH                  4.745562
# 7          India    ETH                  4.311813
# 8           Asia    ETH                  4.270687
# 9         Africa    ETH                  2.927689

# %% [markdown]
# **Question 5**
#
# Which mentors have the largest initial investment in each ticker?

# %%
pd.read_sql_query(
    """
    WITH cte_rank AS (
        SELECT
          first_name,
          ticker,
          initial_investment,
          RANK() OVER (
              PARTITION BY ticker ORDER BY initial_investment DESC
          ) AS investment_rank
        FROM mentor_performance
    )
    SELECT *
    FROM cte_rank
    WHERE investment_rank=1;
    """,
    engine
)
# Out:
#   first_name ticker  initial_investment  investment_rank
# 0       Leah    BTC        6.492218e+07                1
# 1      Vipul    ETH        2.900194e+06                1

# %% [markdown]
# # References
#
# - [Data With Danny Course - Step 12](https://github.com/DataWithDanny/sql-masterclass/blob/main/course-content/step12.md)
